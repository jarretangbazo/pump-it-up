# %% [markdown]
# # 04 - Baseline Models
#
# **Project**: Flu Shot Learning: Predict H1N1 and Seasonal Flu Vaccines
#
# **Author**: Jarret Angbazo
#
# **Date**: May 10, 2026
#
# ---
#
# ## Objective
# Establish baseline performance with simple models:
# - Naive baselines (mean, last value)
# - Linear regression
# - Decision tree
# - Random forest
# - Set performance benchmarks for advanced models

# %% [markdown]
# ## 1. Setup and Imports

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn
from sklearn.model_selection import train_test_split, cross_val_score, TimeSeriesSplit
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## 2. Load Data

# %%
# Load feature-engineered data
# TODO: Load processed data

# %%
# Separate features and target
# TODO: Create X and y

# %% [markdown]
# ## 3. Train-Test Split
#
# ⚠️ **Important**: For time series, use temporal split (not random)

# %%
# Time-based split
# TODO: Split by date, keeping temporal order
# Option 1: Last 20% for test
# Option 2: TimeSeriesSplit for cross-validation

# %% [markdown]
# ## 4. Evaluation Metrics

# %%
# Define evaluation function
def evaluate_model(y_true, y_pred, model_name='Model'):
    """
    Calculate and print regression metrics.
    
    Competition metric is MAE (Mean Absolute Error)
    """
    # TODO: Calculate MAE, RMSE, MAPE, R2
    # TODO: Print formatted results
    # TODO: Return metrics dictionary
    pass

# %% [markdown]
# ## 5. Naive Baselines

# %% [markdown]
# ### 5.1 Mean Baseline
# Predict the mean of training data for all test samples

# %%
# Mean baseline
# TODO: Predict mean of y_train for all test samples

# %% [markdown]
# ### 5.2 Last Value Baseline
# Predict the previous week's value

# %%
# Last value baseline
# TODO: Use lag-1 feature as prediction

# %% [markdown]
# ### 5.3 Seasonal Mean Baseline
# Predict mean for the same week of year from training data

# %%
# Seasonal mean baseline
# TODO: Group by week_of_year and predict mean

# %% [markdown]
# ## 6. Linear Models

# %% [markdown]
# ### 6.1 Simple Linear Regression

# %%
# Train linear regression
# TODO: Fit LinearRegression model

# %%
# Evaluate
# TODO: Make predictions and evaluate

# %% [markdown]
# ### 6.2 Ridge Regression (L2 regularization)

# %%
# Train Ridge regression
# TODO: Fit Ridge model with cross-validation for alpha

# %% [markdown]
# ### 6.3 Lasso Regression (L1 regularization)

# %%
# Train Lasso regression
# TODO: Fit Lasso model

# %% [markdown]
# ## 7. Tree-Based Models

# %% [markdown]
# ### 7.1 Decision Tree

# %%
# Train decision tree
# TODO: Fit DecisionTreeRegressor

# %%
# Feature importance
# TODO: Plot top 10 important features

# %% [markdown]
# ### 7.2 Random Forest

# %%
# Train random forest
# TODO: Fit RandomForestRegressor
# Start with default parameters

# %%
# Feature importance
# TODO: Plot and analyze feature importance

# %% [markdown]
# ## 8. Model Comparison

# %%
# Create comparison dataframe
# TODO: Compare all models on MAE, RMSE, R2

# %%
# Visualize model comparison
# TODO: Bar chart of MAE across models

# %% [markdown]
# ## 9. Prediction Analysis

# %%
# Plot predictions vs actuals for best model
# TODO: Scatter plot and time series plot

# %%
# Residual analysis
# TODO: Plot residuals over time and distribution

# %% [markdown]
# ## 10. Cross-Validation

# %%
# Time series cross-validation
# TODO: Use TimeSeriesSplit to validate best models

# %% [markdown]
# ## 11. Summary
#
# ### Best Baseline Model:
# - Model: TODO
# - MAE: TODO
# - RMSE: TODO
# - R2: TODO
#
# ### Key Findings:
# 1. TODO: Which features are most important?
# 2. TODO: How do models compare?
# 3. TODO: What patterns do residuals show?
#
# ### Next Steps:
# 1. Hyperparameter tuning for top models
# 2. Try gradient boosting (XGBoost, LightGBM)
# 3. Ensemble methods
# 4. Deep learning approaches
