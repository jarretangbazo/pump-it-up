# %% [markdown]
# # 05 - Advanced Models
#
# **Project**: Flu Shot Learning: Predict H1N1 and Seasonal Flu Vaccines
#
# **Author**: Jarret Angbazo
#
# **Date**: May 10, 2026
#
# ---
#
# ## Objective
# Implement and tune advanced models:
# - Gradient boosting (XGBoost, LightGBM, CatBoost)
# - Time series models (SARIMAX, Prophet)
# - Ensemble methods
# - Hyperparameter optimization

# %% [markdown]
# ## 1. Setup and Imports

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# Gradient Boosting
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor

# Time Series
from statsmodels.tsa.statespace.sarimax import SARIMAX
from prophet import Prophet

# Hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import TimeSeriesSplit

# Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error

# MLflow for experiment tracking
import mlflow
import mlflow.sklearn

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## 2. Load Data and Previous Results

# %%
# Load processed data
# TODO: Load train/test data

# %%
# Baseline MAE to beat
baseline_mae = None  # TODO: Add from previous notebook

# %% [markdown]
# ## 3. Gradient Boosting Models

# %% [markdown]
# ### 3.1 XGBoost

# %%
# XGBoost with default parameters
# TODO: Train initial XGBoost model

# %%
# XGBoost hyperparameter tuning
# TODO: Define parameter grid
param_grid = {
    'max_depth': [3, 5, 7, 10],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 500],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]
}

# TODO: Run RandomizedSearchCV or GridSearchCV

# %%
# Feature importance from XGBoost
# TODO: Plot feature importance

# %% [markdown]
# ### 3.2 LightGBM

# %%
# LightGBM model
# TODO: Train LightGBM with default parameters

# %%
# LightGBM hyperparameter tuning
# TODO: Tune parameters

# %% [markdown]
# ### 3.3 CatBoost

# %%
# CatBoost model
# TODO: Train CatBoost

# %% [markdown]
# ## 4. Time Series Specific Models

# %% [markdown]
# ### 4.1 SARIMAX
# Seasonal ARIMA with exogenous variables

# %%
# SARIMAX for each city separately
# TODO: Fit SARIMAX model
# Parameters: (p,d,q) x (P,D,Q,s)
# Use weather variables as exogenous features

# %% [markdown]
# ### 4.2 Prophet
# Facebook Prophet for time series

# %%
# Prophet model
# TODO: Prepare data in Prophet format (ds, y columns)
# TODO: Add weather variables as regressors

# %% [markdown]
# ## 5. Separate Models by City

# %% [markdown]
# ### Hypothesis: San Juan and Iquitos have different patterns
# Train separate models for each city

# %%
# Split data by city
# TODO: Create separate datasets for sj and iq

# %%
# Train city-specific XGBoost models
# TODO: Train and evaluate

# %% [markdown]
# ## 6. Ensemble Methods

# %% [markdown]
# ### 6.1 Voting Regressor
# Average predictions from multiple models

# %%
# Create ensemble of best models
# TODO: Combine XGBoost, LightGBM, Random Forest

# %% [markdown]
# ### 6.2 Stacking
# Use meta-learner on top of base models

# %%
# Stacking ensemble
# TODO: Create stacking regressor with linear meta-learner

# %% [markdown]
# ### 6.3 Weighted Average
# Optimize weights for different models

# %%
# Find optimal weights
# TODO: Grid search over weight combinations

# %% [markdown]
# ## 7. MLflow Experiment Tracking

# %%
# Set up MLflow experiment
mlflow.set_experiment("dengai-advanced-models")

# TODO: Log parameters, metrics, and models for each experiment

# %% [markdown]
# ## 8. Model Comparison

# %%
# Compare all models
# TODO: Create comparison table with MAE, RMSE, R2

# %%
# Visualize model comparison
# TODO: Bar chart and box plots of cross-validation scores

# %% [markdown]
# ## 9. Error Analysis

# %%
# Identify where model fails
# TODO: Plot residuals by:
# - Time period
# - City
# - Season
# - Outbreak vs normal periods

# %%
# Analyze worst predictions
# TODO: What do the worst predicted weeks have in common?

# %% [markdown]
# ## 10. Generate Competition Submission

# %%
# Make predictions on test set
# TODO: Use best model to predict test data

# %%
# Create submission file
# TODO: Format as per competition requirements
# TODO: Save to data/predictions/submission.csv

# %% [markdown]
# ## 11. Summary
#
# ### Best Model:
# - Name: TODO
# - Parameters: TODO
# - CV MAE: TODO
# - Test MAE: TODO
#
# ### Improvement over Baseline:
# - Baseline MAE: TODO
# - Best MAE: TODO
# - Improvement: TODO%
#
# ### Key Insights:
# 1. TODO: What worked best?
# 2. TODO: City-specific models vs combined?
# 3. TODO: Most important features?
# 4. TODO: Ensemble vs single model?
